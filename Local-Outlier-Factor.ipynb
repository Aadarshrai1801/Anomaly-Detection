# %% [markdown]
# ### Local Outlier Factor Implementation

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import LocalOutlierFactor
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles

# %%
# Make the dataset
X, y = make_circles(n_samples=750, factor=0.3, noise=0.1)

# %%
X
# Out:
# array([[-0.89237374, -0.08634329],
#        [ 0.24108147, -0.15859386],
#        [-0.08313691, -0.34090239],
#        ...,
#        [-0.181104  ,  0.18326667],
#        [ 0.25249844, -0.09885137],
#        [-0.22193872, -1.06830403]], shape=(750, 2))

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
lof = LocalOutlierFactor(n_neighbors=5)

# %%
y_pred = lof.fit_predict(X)

# %%
# Plot anomaly detection result
outliers = X[y_pred == -1]
inliers = X[y_pred == 1]

plt.scatter(inliers[:,0], inliers[:,1], label="Normal")
plt.scatter(outliers[:,0], outliers[:,1], color="red", label="Outliers")

plt.legend()
plt.title("LOF Anomaly Detection")
plt.show()
